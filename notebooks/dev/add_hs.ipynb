# %%
from src.data.datasets import *
from src.utils.prolif import *
import rdkit.Chem as Chem
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Running cells with '/Users/charlie/micromamba/envs/poses/bin/python' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p /Users/charlie/micromamba/envs/poses ipykernel --update-deps --force-reinstall'

# %%
dataset = ZINCSamples()
prot, lig = dataset[1]
ref = CrossdockedDataset()[1][1]

# %%
df = generate_interaction_df(prot, lig)
# Out:
#   0%|          | 0/99 [00:00<?, ?it/s]

# %%
len(lig)
# Out:
# 99

# %%
ref[0].GetNumAtoms()
# Out:
# 60

# %%
dm.read_sdf(
    "/Users/charlie/projects/poses_benchmark/data/benchmarks/zinc/1e8h-A-rec-1e8h-adp-lig-tt-min-0-pocket10_zinc.sdf"
)[15]

# %%
lig[13]
# Out:
# <prolif.molecule.Molecule with 1 residues and 32 atoms at 0x17bbfc630>

# %%
ref[0]
# Out:
# <prolif.molecule.Molecule with 1 residues and 60 atoms at 0x179d3a890>

# %%
mols = [Chem.Mol(lig[i]) for i in range(len(lig))]

# %%
num_atoms = [m.GetNumAtoms() for m in mols]
plt.vlines(60, 0, 1000, colors="r", linestyles="dashed")
sns.histplot(num_atoms)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.violinplot(df.groupby(level=2, axis=1).sum())
# Out:
# <Axes: xlabel='interaction'>

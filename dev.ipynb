# %%
import torch
# Out:
# Running cells with '/Users/charlie/micromamba/envs/posecheck/bin/python' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p /Users/charlie/micromamba/envs/posecheck ipykernel --update-deps --force-reinstall'
